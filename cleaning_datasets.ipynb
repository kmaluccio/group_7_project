# %%
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
WHO_data_load = "WHO_AirQuality_Database_2018.csv"
cancer_data_to_load = "500_cancer.csv"
asthma_data_to_load = "500_asthma.csv"
diabetes_data_to_load = "500_diabetes.csv"

# Read the City and Ride Data
air_data_df = pd.read_csv(WHO_data_load)
cancer_data_df = pd.read_csv(cancer_data_to_load)
ashtma_data_df = pd.read_csv(asthma_data_to_load)
diabetes_data_df = pd.read_csv(diabetes_data_to_load)

# %%
air_data_df
# Out:
#        ID WHO city iso3       country           city        pm10  Year  \
# 0              3.0  ALB       Albania         Tirana   31.615421  2013
# 1             15.0  AUS     Australia  Central Coast   12.820462  2014
# 2             18.0  AUS     Australia      Devonport   14.918356  2013
# 3             19.0  AUS     Australia        Geelong   17.500000  2014
# 4             22.0  AUS     Australia         Hobart   14.219058  2013
# ...            ...  ...           ...            ...         ...   ...
# 11966          NaN  SAU  Saudi Arabia         Riyadh  201.000000  2014
# 11967          NaN  SAU  Saudi Arabia         Riyadh  240.000000  2015
# 11968          NaN  SAU  Saudi Arabia         Riyadh  251.000000  2016
# 11969          NaN  SAU  Saudi Arabia         Dammam  260.000000  2015
# 11970          NaN  SAU  Saudi Arabia         Dammam  161.000000  2016
#
#                             type_of_stations  pm10_type       pm25  pm25_type  \
# 0                  1 station, traffic, urban   Measured  16.062366   Measured
# 1                                          -  Converted   5.500000   Measured
# 2                                          -  Converted   6.400000   Measured
# 3      1 station, Residential/Light Industry   Measured   7.507530  Converted
# 4                                          -  Converted   6.100000   Measured
# ...                                      ...        ...        ...        ...
# 11966                                 1 N.A.   Measured  51.000000   Measured
# 11967                                 1 N.A.   Measured  69.000000   Measured
# 11968                                 1 N.A.   Measured  73.000000   Measured
# 11969                                 1 N.A.   Measured  61.000000   Measured
# 11970                                 1 N.A.   Measured  56.000000   Measured
#
#        ... latitude_pop  longitude_pop                       Region  \
# 0      ...          NaN            NaN                Europe (LMIC)
# 1      ...          NaN            NaN        Western Pacific (HIC)
# 2      ...          NaN            NaN        Western Pacific (HIC)
# 3      ...          NaN            NaN        Western Pacific (HIC)
# 4      ...          NaN            NaN        Western Pacific (HIC)
# ...    ...          ...            ...                          ...
# 11966  ...    24.690466      46.709566  Eastern Mediterranean (HIC)
# 11967  ...    24.690466      46.709566  Eastern Mediterranean (HIC)
# 11968  ...    24.690466      46.709566  Eastern Mediterranean (HIC)
# 11969  ...    26.392666      49.977715  Eastern Mediterranean (HIC)
# 11970  ...    26.392666      49.977715  Eastern Mediterranean (HIC)
#
#        region_abbr tempcov_PM10_grad tempcov_PM25_grad  conc_pm25 color_pm25  \
# 0       Eur (LMIC)               NaN               NaN     15-<25     orange
# 1        Wpr (HIC)               NaN               NaN        <10      green
# 2        Wpr (HIC)               NaN               NaN        <10      green
# 3        Wpr (HIC)               NaN               NaN        <10      green
# 4        Wpr (HIC)               NaN               NaN        <10      green
# ...            ...               ...               ...        ...        ...
# 11966    Emr (HIC)               NaN               NaN        >50    darkred
# 11967    Emr (HIC)               NaN               NaN        >50    darkred
# 11968    Emr (HIC)               NaN               NaN        >50    darkred
# 11969    Emr (HIC)               NaN               NaN        >50    darkred
# 11970    Emr (HIC)               NaN               NaN        >50    darkred
#
#        conc_pm10  color_pm10
# 0         30-<50     darkred
# 1            <20       green
# 2            <20       green
# 3            <20       green
# 4            <20       green
# ...          ...         ...
# 11966       >100     darkred
# 11967       >100     darkred
# 11968       >100     darkred
# 11969       >100     darkred
# 11970       >100     darkred
#
# [11971 rows x 30 columns]

# %%
# filter for USA data only
air_data_df = air_data_df.loc[air_data_df["country"] == "United States of America"]

# change city to CityName
air_data_df = air_data_df.rename(columns={"city":"CityName"})

air_data_df.head()
# Out:
#      ID WHO city iso3                   country                 CityName  \
# 639       2604.0  USA  United States of America                   Adrian
# 640       2605.0  USA  United States of America                    Akron
# 641       2606.0  USA  United States of America  Albany-Schenectady-Troy
# 642       2608.0  USA  United States of America               Alexandria
# 643       2609.0  USA  United States of America                  Allegan
#
#           pm10  Year type_of_stations  pm10_type  pm25 pm25_type  ...  \
# 639  16.252915  2014                -  Converted   8.8  Measured  ...
# 640  19.207991  2014                -  Converted  10.4  Measured  ...
# 641  13.482532  2014                -  Converted   7.3  Measured  ...
# 642  14.221301  2014                -  Converted   7.7  Measured  ...
# 643  16.068223  2014                -  Converted   8.7  Measured  ...
#
#     latitude_pop  longitude_pop          Region  region_abbr  \
# 639          NaN            NaN  Americas (HIC)    Amr (HIC)
# 640          NaN            NaN  Americas (HIC)    Amr (HIC)
# 641          NaN            NaN  Americas (HIC)    Amr (HIC)
# 642          NaN            NaN  Americas (HIC)    Amr (HIC)
# 643          NaN            NaN  Americas (HIC)    Amr (HIC)
#
#     tempcov_PM10_grad tempcov_PM25_grad  conc_pm25 color_pm25  conc_pm10  \
# 639               NaN               NaN        <10      green        <20
# 640               NaN               NaN     10-<15     yellow        <20
# 641               NaN               NaN        <10      green        <20
# 642               NaN               NaN        <10      green        <20
# 643               NaN               NaN        <10      green        <20
#
#      color_pm10
# 639       green
# 640       green
# 641       green
# 642       green
# 643       green
#
# [5 rows x 30 columns]

# %%
air_cities = air_data_df["CityName"].unique()

air_cities = np.array(air_cities).tolist()

# %%
diabetes_cities = diabetes_data_df["CityName"].unique()

diabetes_cities = np.array(diabetes_cities).tolist()

diabetes_cities
# Out:
# ['Inglewood',
#  'Huntsville',
#  'Anchorage',
#  'Tempe',
#  'Yuma',
#  'Antioch',
#  'Burbank',
#  'Folsom',
#  'Moreno Valley',
#  'Palmdale',
#  'Riverside',
#  'Roseville',
#  'San Francisco',
#  'San Jose',
#  'Stamford',
#  'Wilmington',
#  'Cape Coral',
#  'Hollywood',
#  'Melbourne',
#  'Pompano Beach',
#  'Santa Clara',
#  'Santa Maria',
#  'Thousand Oaks',
#  'Union City',
#  'Vacaville',
#  'West Covina',
#  'Fort Collins',
#  'Thornton',
#  'Lafayette',
#  'Des Moines',
#  'Sioux City',
#  'Olathe',
#  'Boston',
#  'Cambridge',
#  'Brooklyn Park',
#  'Gulfport',
#  'Manchester',
#  'Nashua',
#  'Jersey City',
#  'New York',
#  'Rochester',
#  'Syracuse',
#  'Yonkers',
#  'Asheville',
#  'Charlotte',
#  'Concord',
#  'Fayetteville',
#  'Raleigh',
#  'Fargo',
#  'Cleveland',
#  'Columbus',
#  'Broken Arrow',
#  'Lawton',
#  'Tulsa',
#  'Gresham',
#  'Salem',
#  'Bethlehem',
#  'Erie',
#  'Warwick',
#  'Columbia',
#  'Knoxville',
#  'Memphis',
#  'Austin',
#  'Beaumont',
#  'Dallas',
#  'Fort Worth',
#  'Garland',
#  'Alexandria',
#  'Chesapeake',
#  'Hampton',
#  'Newport News',
#  'Virginia Beach',
#  'Federal Way',
#  'Yakima',
#  'Green Bay',
#  'Gilbert',
#  'Milwaukee',
#  'Waukesha',
#  'Birmingham',
#  'Chandler',
#  'Mobile',
#  'Hoover',
#  'Tuscaloosa',
#  'Montgomery',
#  'Avondale',
#  nan,
#  'Killeen',
#  'Longview',
#  'McKinney',
#  'Plano',
#  'Phoenix',
#  'Glendale',
#  'Mesa',
#  'Peoria',
#  'Corona',
#  'Anaheim',
#  'Tucson',
#  'Little Rock',
#  'Surprise',
#  'Alhambra',
#  'Scottsdale',
#  'Springdale',
#  'Fort Smith',
#  'Jonesboro',
#  'Alameda',
#  'Daly City',
#  'Bakersfield',
#  'Berkeley',
#  'Chula Vista',
#  'Bellflower',
#  'Compton',
#  'Downey',
#  'Carson',
#  'Carlsbad',
#  'Buena Park',
#  'Citrus Heights',
#  'Chino',
#  'Costa Mesa',
#  'Apple Valley',
#  'Clovis',
#  'Baldwin Park',
#  'Chico',
#  'Chino Hills',
#  'Long Beach',
#  'Elk Grove',
#  'Fresno',
#  'El Cajon',
#  'Fontana',
#  'Escondido',
#  'El Monte',
#  'Hayward',
#  'Hawthorne',
#  'Fullerton',
#  'Fairfield',
#  'Fremont',
#  'Garden Grove',
#  'Lake Forest',
#  'Irvine',
#  'Huntington Beach',
#  'Lakewood',
#  'Lancaster',
#  'Hesperia',
#  'Indio',
#  'Hemet',
#  'Livermore',
#  'Arvada',
#  'Los Angeles',
#  'Mission Viejo',
#  'Newport Beach',
#  'Menifee',
#  'Napa',
#  'Murrieta',
#  'Manteca',
#  'Milpitas',
#  'Modesto',
#  'Merced',
#  'Mountain View',
#  'Norwalk',
#  'Lynwood',
#  'San Diego',
#  'Oakland',
#  'Rialto',
#  'Orange',
#  'Pomona',
#  'Richmond',
#  'Rancho Cucamonga',
#  'Pleasanton',
#  'Oxnard',
#  'Redding',
#  'Pasadena',
#  'Redlands',
#  'Ontario',
#  'Redwood City',
#  'Perris',
#  'Oceanside',
#  'Redondo Beach',
#  'Sacramento',
#  'San Bernardino',
#  'Salinas',
#  'San Buenaventura (Ventura)',
#  'Whittier',
#  'San Mateo',
#  'San Ramon',
#  'San Marcos',
#  'San Leandro',
#  'Westminster',
#  'Vallejo',
#  'Santa Barbara',
#  'Torrance',
#  'Simi Valley',
#  'Santa Ana',
#  'Stockton',
#  'Upland',
#  'Tustin',
#  'Turlock',
#  'Santa Clarita',
#  'Tracy',
#  'Santa Rosa',
#  'South Gate',
#  'Temecula',
#  'Sunnyvale',
#  'Santa Monica',
#  'Bridgeport',
#  'Visalia',
#  'Denver',
#  'Boulder',
#  'Colorado Springs',
#  'Victorville',
#  'Aurora',
#  'Centennial',
#  'Vista',
#  'Chicago',
#  'Longmont',
#  'New Britain',
#  'Waterbury',
#  'Danbury',
#  'Pueblo',
#  'New Haven',
#  'Hartford',
#  'Greeley',
#  'Loveland',
#  'Gainesville',
#  'Clearwater',
#  'Hialeah',
#  'Coral Springs',
#  'Washington',
#  'Deerfield Beach',
#  'Fort Lauderdale',
#  'Davie',
#  'Deltona',
#  'Boca Raton',
#  'Boynton Beach',
#  'Jacksonville',
#  'Lakeland',
#  'Orlando',
#  'Miami',
#  'Palm Bay',
#  'Lauderhill',
#  'Palm Coast',
#  'Largo',
#  'Miami Beach',
#  'Miami Gardens',
#  'Miramar',
#  'St. Petersburg',
#  'Tampa',
#  'Tallahassee',
#  'Sunrise',
#  'Port St. Lucie',
#  'Pembroke Pines',
#  'Atlanta',
#  'Athens',
#  'West Palm Beach',
#  'Plantation',
#  'Albany',
#  'Honolulu',
#  'Boise City',
#  'Macon',
#  'Augusta',
#  'Nampa',
#  'Savannah',
#  'Johns Creek',
#  'Sandy Springs',
#  'Meridian',
#  'Roswell',
#  'Warner Robins',
#  'Bloomington',
#  'Bolingbrook',
#  'Champaign',
#  'Arlington Heights',
#  'Elgin',
#  'Palatine',
#  'Evanston',
#  'Decatur',
#  'Cicero',
#  'Naperville',
#  'Joliet',
#  'Waukegan',
#  'Indianapolis',
#  'Evansville',
#  'Rockford',
#  'Gary',
#  'Springfield',
#  'Fort Wayne',
#  'Fishers',
#  'Schaumburg',
#  'Carmel',
#  'Hammond',
#  'Wichita',
#  'New Orleans',
#  'Overland Park',
#  'Muncie',
#  'Topeka',
#  'South Bend',
#  'Waterloo',
#  'Lawrence',
#  'Kansas City',
#  'Cedar Rapids',
#  'Davenport',
#  'Iowa City',
#  'Baton Rouge',
#  'Louisville',
#  'Lake Charles',
#  'Lexington',
#  'Kenner',
#  'Baltimore',
#  'Brockton',
#  'Shreveport',
#  'Detroit',
#  'Portland',
#  'Lowell',
#  'Lynn',
#  'New Bedford',
#  'Ann Arbor',
#  'Fall River',
#  'Quincy',
#  'Worcester',
#  'Somerville',
#  'Dearborn',
#  'Newton',
#  'Grand Rapids',
#  'Sterling Heights',
#  'Duluth',
#  'Kalamazoo',
#  'Westland',
#  'Lansing',
#  'Flint',
#  'Warren',
#  'Wyoming',
#  'Livonia',
#  'Southfield',
#  'Farmington Hills',
#  'Rochester Hills',
#  'Troy',
#  'Paterson',
#  'Plymouth',
#  'Minneapolis',
#  'Jackson',
#  'Independence',
#  'St. Joseph',
#  "Lee's Summit",
#  'St. Paul',
#  "O'Fallon",
#  'Las Vegas',
#  'Omaha',
#  'Billings',
#  'St. Louis',
#  'Henderson',
#  'Lincoln',
#  'Missoula',
#  'Clifton',
#  'Sparks',
#  'Reno',
#  'North Las Vegas',
#  'Newark',
#  'Camden',
#  'Elizabeth',
#  'Passaic',
#  'Trenton',
#  'Albuquerque',
#  'Santa Fe',
#  'Mount Vernon',
#  'Las Cruces',
#  'Buffalo',
#  'New Rochelle',
#  'Gastonia',
#  'Rio Rancho',
#  'Durham',
#  'Winston-Salem',
#  'Greenville',
#  'Cary',
#  'Schenectady',
#  'Greensboro',
#  'High Point',
#  'Cincinnati',
#  'Canton',
#  'Akron',
#  'Rock Hill',
#  'Oklahoma City',
#  'Parma',
#  'Dayton',
#  'Edmond',
#  'Norman',
#  'Youngstown',
#  'Toledo',
#  'Sioux Falls',
#  'Beaverton',
#  'Medford',
#  'Eugene',
#  'Bend',
#  'Hillsboro',
#  'Philadelphia',
#  'Pittsburgh',
#  'Allentown',
#  'Arlington',
#  'Rapid City',
#  'Charleston',
#  'Scranton',
#  'Chattanooga',
#  'Clarksville',
#  'Providence',
#  'North Charleston',
#  'Reading',
#  'Pawtucket',
#  'Mount Pleasant',
#  'Cranston',
#  'Amarillo',
#  'Murfreesboro',
#  'Abilene',
#  'Nashville',
#  'Allen',
#  'Brownsville',
#  'Baytown',
#  'Carrollton',
#  'Corpus Christi',
#  'College Station',
#  'Bryan',
#  'El Paso',
#  'Denton',
#  'Frisco',
#  'Edinburg',
#  'Houston',
#  'Grand Prairie',
#  'Laredo',
#  'Lewisville',
#  'Lubbock',
#  'Mission',
#  'Mesquite',
#  'McAllen',
#  'Missouri City',
#  'Odessa',
#  'League City',
#  'Midland',
#  'Pearland',
#  'Irving',
#  'Kenosha',
#  'Vancouver',
#  'San Antonio',
#  'San Angelo',
#  'Waco',
#  'Wichita Falls',
#  'Pharr',
#  'Round Rock',
#  'Richardson',
#  'Sugar Land',
#  'Tyler',
#  'Ogden',
#  'Portsmouth',
#  'Provo',
#  'West Jordan',
#  'Sandy',
#  'Norfolk',
#  'Burlington',
#  'Orem',
#  'Layton',
#  'West Valley City',
#  'Lynchburg',
#  'Salt Lake City',
#  'St. George',
#  'Kennewick',
#  'Suffolk',
#  'Seattle',
#  'Auburn',
#  'Kent',
#  'Bellingham',
#  'Everett',
#  'Roanoke',
#  'Renton',
#  'Bellevue',
#  'Spokane',
#  'Appleton',
#  'Spokane Valley',
#  'Tacoma',
#  'Cheyenne',
#  'Madison',
#  'Racine']

# %%
new_cities = []

# create a for loop for each city list that checks if the city name matches
for city in air_cities:
    for i in diabetes_cities:
        if city == i:
            new_cities.append(city)

print(new_cities)
# Out:
# ['Akron', 'Alexandria', 'Ann Arbor', 'Asheville', 'Athens', 'Boulder', 'Cambridge', 'Chattanooga', 'Cheyenne', 'Colorado Springs', 'Corpus Christi', 'Dayton', 'Decatur', 'Evansville', 'Fargo', 'Flint', 'Fort Smith', 'Gainesville', 'Greeley', 'Hammond', 'Huntsville', 'Jackson', 'Lafayette', 'Lake Charles', 'Lakeland', 'Lincoln', 'Lynchburg', 'Medford', 'Merced', 'Mobile', 'Montgomery', 'Muncie', 'Oklahoma City', 'Pueblo', 'Reading', 'Redding', 'Roanoke', 'San Antonio', 'Sioux City', 'Sioux Falls', 'Spokane', 'Syracuse', 'Tallahassee', 'Toledo', 'Topeka', 'Tucson', 'Tuscaloosa', 'Warner Robins', 'Wichita', 'Albany', 'Albuquerque', 'Allentown', 'Anaheim', 'Anchorage', 'Apple Valley', 'Appleton', 'Atlanta', 'Auburn', 'Bakersfield', 'Baltimore', 'Baton Rouge', 'Bellevue', 'Bellingham', 'Bloomington', 'Boston', 'Bridgeport', 'Brockton', 'Burlington', 'Camden', 'Cedar Rapids', 'Charleston', 'Chico', 'Clarksville', 'Cleveland', 'Clovis', 'Columbia', 'Columbus', 'Concord', 'Dallas', 'Davenport', 'Davie', 'Denver', 'Des Moines', 'Detroit', 'Duluth', 'Durham', 'El Paso', 'Elizabeth', 'Erie', 'Fall River', 'Fayetteville', 'Folsom', 'Fort Collins', 'Fort Wayne', 'Fresno', 'Gary', 'Glendale', 'Green Bay', 'Greensboro', 'Greenville', 'Hartford', 'Henderson', 'Honolulu', 'Houston', 'Iowa City', 'Jacksonville', 'Jersey City', 'Kansas City', 'Kenner', 'Kent', 'Knoxville', 'Lancaster', 'Las Vegas', 'Lawton', 'Lexington', 'Livermore', 'Long Beach', 'Los Angeles', 'Louisville', 'Lynn', 'Macon', 'Madison', 'Memphis', 'Mesa', 'Miami', 'Minneapolis', 'Missoula', 'Modesto', 'Mountain View', 'Napa', 'Nashville', 'New Haven', 'New York', 'Newark', 'North Charleston', 'North Las Vegas', 'Oakland', 'Ogden', 'Omaha', 'Ontario', 'Philadelphia', 'Phoenix', 'Pittsburgh', 'Portland', 'Portsmouth', 'Providence', 'Provo', 'Quincy', 'Raleigh', 'Rapid City', 'Redwood City', 'Reno', 'Richmond', 'Rochester', 'Salinas', 'Salt Lake City', 'San Diego', 'San Francisco', 'San Jose', 'Santa Barbara', 'Santa Maria', 'Scranton', 'Seattle', 'Simi Valley', 'South Bend', 'Sparks', 'Springfield', 'St. Joseph', 'St. Louis', 'St. Paul', 'Stockton', 'Tacoma', 'Tampa', 'Tempe', 'Thousand Oaks', 'Trenton', 'Tulsa', 'Vallejo', 'Victorville', 'Virginia Beach', 'Washington', 'Waterbury', 'Wilmington', 'Winston-Salem', 'Worcester', 'Yakima', 'Yuma']

# %%
clean_air_df = air_data_df.loc[air_data_df['CityName'].isin(new_cities)]

clean_air_df.head()
# Out:
#      ID WHO city iso3                   country    CityName       pm10  Year  \
# 640       2605.0  USA  United States of America       Akron  19.207991  2014
# 642       2608.0  USA  United States of America  Alexandria  14.221301  2014
# 645       2614.0  USA  United States of America   Ann Arbor  18.099838  2014
# 646       2616.0  USA  United States of America   Asheville  14.405993  2014
# 648       2618.0  USA  United States of America      Athens  14.405993  2014
#
#     type_of_stations  pm10_type  pm25 pm25_type  ... latitude_pop  \
# 640                -  Converted  10.4  Measured  ...          NaN
# 642                -  Converted   7.7  Measured  ...          NaN
# 645                -  Converted   9.8  Measured  ...          NaN
# 646                -  Converted   7.8  Measured  ...          NaN
# 648                -  Converted   7.8  Measured  ...          NaN
#
#      longitude_pop          Region  region_abbr tempcov_PM10_grad  \
# 640            NaN  Americas (HIC)    Amr (HIC)               NaN
# 642            NaN  Americas (HIC)    Amr (HIC)               NaN
# 645            NaN  Americas (HIC)    Amr (HIC)               NaN
# 646            NaN  Americas (HIC)    Amr (HIC)               NaN
# 648            NaN  Americas (HIC)    Amr (HIC)               NaN
#
#     tempcov_PM25_grad  conc_pm25 color_pm25  conc_pm10  color_pm10
# 640               NaN     10-<15     yellow        <20       green
# 642               NaN        <10      green        <20       green
# 645               NaN        <10      green        <20       green
# 646               NaN        <10      green        <20       green
# 648               NaN        <10      green        <20       green
#
# [5 rows x 30 columns]

# %%
# clean diabetes 
clean_diabetes_df = diabetes_data_df.loc[diabetes_data_df['CityName'].isin(new_cities)]

clean_diabetes_df.head()
# Out:
#    Year StateAbbr   StateDesc    CityName GeographicLevel DataSource  \
# 1  2017        AL     Alabama  Huntsville    Census Tract      BRFSS
# 2  2017        AK      Alaska   Anchorage    Census Tract      BRFSS
# 3  2017        AZ     Arizona       Tempe    Census Tract      BRFSS
# 4  2017        AZ     Arizona        Yuma            City      BRFSS
# 7  2017        CA  California      Folsom            City      BRFSS
#
#           Category             UniqueID  \
# 1  Health Outcomes  0137000-01089002922
# 2  Health Outcomes  0203000-02020002501
# 3  Health Outcomes  0473000-04013319907
# 4  Health Outcomes              0485540
# 7  Health Outcomes              0624638
#
#                                            Measure Data_Value_Unit  ...  \
# 1  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 2  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 3  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 4  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 7  Diagnosed diabetes among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 1                  10.3                        NaN                  NaN
# 2                   7.8                        NaN                  NaN
# 3                   7.9                        NaN                  NaN
# 4                  11.3                        NaN                  NaN
# 7                   7.3                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 1             4387   (34.612755588, -86.5329568642)    HLTHOUT  DIABETES
# 2             4993  (61.1593945029, -149.899866691)    HLTHOUT  DIABETES
# 3             2225  (33.3419171912, -111.919809152)    HLTHOUT  DIABETES
# 4            93064   (32.5986027117, -114.54836837)    HLTHOUT  DIABETES
# 7            72203  (38.6750494328, -121.147605753)    HLTHOUT  DIABETES
#
#    CityFIPS     TractFIPS Short_Question_Text
# 1  137000.0  1.089003e+09            Diabetes
# 2  203000.0  2.020003e+09            Diabetes
# 3  473000.0  4.013320e+09            Diabetes
# 4  485540.0           NaN            Diabetes
# 7  624638.0           NaN            Diabetes
#
# [5 rows x 24 columns]

# %%
# Merge the datasets together

clean_air_dia_df = pd.merge(clean_air_df, clean_diabetes_df, how="left", on=["CityName","CityName"])


clean_air_dia_df
# Out:
#        ID WHO city iso3                   country CityName       pm10  Year_x  \
# 0           2605.0  USA  United States of America    Akron  19.207991    2014
# 1           2605.0  USA  United States of America    Akron  19.207991    2014
# 2           2605.0  USA  United States of America    Akron  19.207991    2014
# 3           2605.0  USA  United States of America    Akron  19.207991    2014
# 4           2605.0  USA  United States of America    Akron  19.207991    2014
# ...            ...  ...                       ...      ...        ...     ...
# 39185          NaN  USA  United States of America     Yuma  17.307898    2016
# 39186          NaN  USA  United States of America     Yuma  17.307898    2016
# 39187          NaN  USA  United States of America     Yuma  17.307898    2016
# 39188          NaN  USA  United States of America     Yuma  17.307898    2016
# 39189          NaN  USA  United States of America     Yuma  17.307898    2016
#
#               type_of_stations  pm10_type  pm25 pm25_type  ...  \
# 0                            -  Converted  10.4  Measured  ...
# 1                            -  Converted  10.4  Measured  ...
# 2                            -  Converted  10.4  Measured  ...
# 3                            -  Converted  10.4  Measured  ...
# 4                            -  Converted  10.4  Measured  ...
# ...                        ...        ...   ...       ...  ...
# 39185  1 Urban And Center City  Converted   8.3  Measured  ...
# 39186  1 Urban And Center City  Converted   8.3  Measured  ...
# 39187  1 Urban And Center City  Converted   8.3  Measured  ...
# 39188  1 Urban And Center City  Converted   8.3  Measured  ...
# 39189  1 Urban And Center City  Converted   8.3  Measured  ...
#
#       High_Confidence_Limit  Data_Value_Footnote_Symbol  \
# 0                      12.9                         NaN
# 1                      25.7                         NaN
# 2                      18.6                         NaN
# 3                      15.6                         NaN
# 4                      11.1                         NaN
# ...                     ...                         ...
# 39185                  10.8                         NaN
# 39186                   NaN                           *
# 39187                  17.1                         NaN
# 39188                   NaN                           *
# 39189                  12.9                         NaN
#
#                                     Data_Value_Footnote  PopulationCount  \
# 0                                                   NaN             6574
# 1                                                   NaN             2913
# 2                                                   NaN             1491
# 3                                                   NaN             5642
# 4                                                   NaN             2910
# ...                                                 ...              ...
# 39185                                               NaN             2922
# 39186  Estimates suppressed for population less than 50                8
# 39187                                               NaN             1108
# 39188  Estimates suppressed for population less than 50                6
# 39189                                               NaN             2502
#
#                            GeoLocation CategoryID  MeasureId   CityFIPS  \
# 0      (41.0807560689, -81.4503350072)    HLTHOUT   DIABETES  3901000.0
# 1      (41.0806403452, -81.5509027089)    HLTHOUT   DIABETES  3901000.0
# 2      (41.0499564598, -81.5233458795)    HLTHOUT   DIABETES  3901000.0
# 3      (41.0968405496, -81.4884726996)    HLTHOUT   DIABETES  3901000.0
# 4       (41.095228314, -81.5489870893)    HLTHOUT   DIABETES  3901000.0
# ...                                ...        ...        ...        ...
# 39185   (32.691176796, -114.654751847)    HLTHOUT   DIABETES   485540.0
# 39186  (32.7054763729, -114.600679055)    HLTHOUT   DIABETES   485540.0
# 39187  (32.6729492819, -114.626631938)    HLTHOUT   DIABETES   485540.0
# 39188  (32.6322428642, -114.487294845)    HLTHOUT   DIABETES   485540.0
# 39189  (32.7125974415, -114.618176873)    HLTHOUT   DIABETES   485540.0
#
#           TractFIPS  Short_Question_Text
# 0      3.915350e+10             Diabetes
# 1      3.915351e+10             Diabetes
# 2      3.915350e+10             Diabetes
# 3      3.915350e+10             Diabetes
# 4      3.915351e+10             Diabetes
# ...             ...                  ...
# 39185  4.027001e+09             Diabetes
# 39186  4.027011e+09             Diabetes
# 39187  4.027001e+09             Diabetes
# 39188  4.027011e+09             Diabetes
# 39189  4.027000e+09             Diabetes
#
# [39190 rows x 53 columns]

# %%
# export the csv for Air_Diabetes

clean_air_dia_df.to_csv('Air_v_Diabetes_Database.csv')
